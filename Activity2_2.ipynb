# %% [markdown]
# # Activity 2 Part 2 - Verification the query results from the CSV Files

# %%
library(dplyr)
players <- read.csv("players.csv", header= TRUE)
teams <- read.csv("teams.csv", header= TRUE)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 3.3.3"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# ### Verification of the player data

# %%
players
# Out:
#       X     player_api_id player_name              overall_rating gk_rating
# 1      1    2625          Patryk Rachwal,18        63             153
# 2      2    2752          Diego Mainz              72              53
# 3      3    2768          Jose Dorado              75             128
# 4      4    2770          Ignacio Gonzalez         74             148
# 5      5    2790          Alberto Rey              73             144
# 6      6    2796          Javier Jimenez           69             340
# 7      7    2802          Pablo Hernandez          82             146
# 8      8    2805          Ruben Perez              76             141
# 9      9    2857          Ivan Perez               72             143
# 10    10    2862          Vicente Sanchez          76             146
# 11    11    2907          Gregory Lacombe          68             135
# 12    12    2973          Ugur Inceman             72             147
# ...

# %% [markdown]
# ### Verification of the Team Data

# %%
teams
# Out:
#     X   team_api_id team_long_name               team_short_name goals_scored
# 1    1  1601        Ruch Chorzów                 CHO             280
# 2    2  1773        Oud-Heverlee Leuven          O-H             126
# 3    3  1957        Jagiellonia Bialystok        BIA             287
# 4    4  2033        S.C. Olhanense               OLH             138
# 5    5  2182        Lech Poznan                  POZ             372
# 6    6  2183        P. Warszawa                  PWA             184
# 7    7  2186        Cracovia                     CKR             235
# 8    8  4049        Tubize                       TUB              35
# 9    9  4064        Feirense                     FEI              27
# 10  10  4087        Évian Thonon Gaillard FC     ETG             180
# 11  11  4170        US Boulogne Cote D'Opale     BOU              31
# 12  12  6269        Novara                       NOV              34
# ...

# %% [markdown]
# ### Top 10 players with the highest overall rating

# %%
rtg <- select(players, player_api_id, player_name, overall_rating)
top_n(arrange(rtg, desc(overall_rating)),10)
# Out:
# Selecting by overall_rating
#    player_api_id player_name       overall_rating
# 1  30981         Lionel Messi      94
# 2  30717         Gianluigi Buffon  93
# 3  30829         Wayne Rooney      93
# 4  30893         Cristiano Ronaldo 93
# 5  39854         Xavi Hernandez    92
# 6  39989         Gregory Coupet    92
# 7  30626         Thierry Henry     91
# 8  30627         John Terry        91
# 9  30657         Iker Casillas     91
# 10 30723         Alessandro Nesta  91
# 11 30743         Ronaldinho        91
# 12 30955         Andres Iniesta    91
# 13 34520         Fabio Cannavaro   91

# %% [markdown]
# ### Top 10 players with the highest goal keeper rating

# %%
gk <- select(players, player_api_id, player_name, gk_rating)
top_n(arrange(gk, desc(gk_rating)),10)
# Out:
# Selecting by gk_rating
#    player_api_id player_name       gk_rating
# 1   30717        Gianluigi Buffon  449
# 2   39989        Gregory Coupet    447
# 3   30859        Petr Cech         445
# 4   30657        Iker Casillas     442
# 5   27299        Manuel Neuer      440
# 6   30989        Julio Cesar       438
# 7   24503        Sebastian Frey    437
# 8   30726        Edwin van der Sar 436
# 9  182917        David De Gea      429
# 10  30660        Pepe Reina        428

# %% [markdown]
# ### Top 10 players with highest appearances

# %%
app <- select(players, player_api_id, player_name, appearances)
top_n(arrange(app, desc(appearances)),10)
# Out:
# Selecting by appearances
#    player_api_id player_name          appearances
# 1  31293         Steve Mandanda       300
# 2  41097         Stephane Ruffier     294
# 3  33764         Gorka Iraizoz Moreno 286
# 4  42422         Samir Handanovic     286
# 5  26295         Hugo Lloris          282
# 6  31465         Tim Howard           282
# 7  31432         Joe Hart             275
# 8  26168         Cedric Carrasso      268
# 9  26399         Daniel Congre        262
# 10 94550         Moussa Sissoko       260

# %% [markdown]
# ### Top 10 players who played in the most number of leagues

# %%
lgc <- select(players, player_api_id, player_name, league_count)
top_n(arrange(lgc, desc(league_count)),10)
# Out:
# Selecting by league_count
#    player_api_id player_name             league_count
# 1   42119        Gelson Fernandes        6
# 2  116750        Ricky van Wolfswinkel   5
# 3  178538        Filip Djuricic          5
# 4   22543        Radamel Falcao          4
# 5   24123        Jonathan De Guzman      4
# 6   25816        Almen Abdi              4
# 7   26434        Ibrahim Afellay         4
# 8   26489        Edson Braafheid         4
# 9   26675        Eljero Elia             4
# 10  30477        Danijel Pranjic         4
# 11  30692        Oguchi Onyewu           4
# 12  30841        Maarten Stekelenburg    4
# 13  30890        Philippe Senderos       4
# 14  30918        David Rozehnal          4
# 15  31294        Niki Zimling            4
# 16  31300        Rolando                 4
# 17  32937        Christian Poulsen       4
# 18  33074        Eidur Gudjohnsen        4
# 19  36784        Klaas Jan Huntelaar     4
# 20  38229        Bryan Ruiz              4
# ...

# %% [markdown]
# ### Top 10 teams with the highest buildup score

# %%
bs <- select(teams, team_api_id, team_short_name, team_long_name, buildupScore)
top_n(arrange(bs, desc(buildupScore)),10)
# Out:
# Selecting by buildupScore
#    team_api_id team_short_name team_long_name             buildupScore
# 1    9804      TOR             Torino                     209
# 2    8600      UDI             Udinese                    205
# 3    8194      FDU             Fortuna Düsseldorf         198
# 4    8033      POD             Podbeskidzie Bielsko-Biala 193
# 5    8245      KKI             Korona Kielce              192
# 6    8024      WID             Widzew Lódz                190
# 7    8244      LOD             Widzew Lódz                190
# 8  208931      CAP             Carpi                      190
# 9    9830      NAN             FC Nantes                  189
# 10   7943      SAS             Sassuolo                   188
# 11   8543      LAZ             Lazio                      188

# %% [markdown]
# ### Top 10 teams with the highest chance creation score

# %%
cs <- select(teams, team_api_id, team_short_name, team_long_name, chanceCreationScore)
top_n(arrange(cs, desc(chanceCreationScore)),10)
# Out:
# Selecting by chanceCreationScore
#    team_api_id team_short_name team_long_name          chanceCreationScore
# 1   8543       LAZ             Lazio                   220
# 2   8697       WBR             SV Werder Bremen        216
# 3   9875       NAP             Napoli                  215
# 4   8178       LEV             Bayer 04 Leverkusen     210
# 5   8191       BUR             Burnley                 210
# 6   8344       CAR             Cardiff City            210
# 7   8456       MCI             Manchester City         210
# 8   8485       ABE             Aberdeen                210
# 9   8548       RAN             Rangers                 210
# 10  8586       TOT             Tottenham Hotspur       210
# 11  8592       MAR             Olympique de Marseille  210
# 12  8602       WOL             Wolverhampton Wanderers 210
# 13  8658       BIR             Birmingham City         210
# 14  8721       WOL             VfL Wolfsburg           210
# ...

# %% [markdown]
# ### Top 10 teams with the highest defense score

# %%
ds <- select(teams, team_api_id, team_short_name, team_long_name, defenseScore)
top_n(arrange(ds, desc(defenseScore)),10)
# Out:
# Selecting by defenseScore
#    team_api_id team_short_name team_long_name          defenseScore
# 1   1957       BIA             Jagiellonia Bialystok   210
# 2   7794       BAS             SC Bastia               210
# 3   8021       ZAG             Zaglebie Lubin          210
# 4   8197       LEI             Leicester City          210
# 5   8344       CAR             Cardiff City            210
# 6   8350       KAI             1. FC Kaiserslautern    210
# 7   8466       SOU             Southampton             210
# 8   8481       NAN             AS Nancy-Lorraine       210
# 9   8483       BLA             Blackpool               210
# 10  8521       BRE             Stade Brestois 29       210
# 11  8602       WOL             Wolverhampton Wanderers 210
# 12  8658       BIR             Birmingham City         210
# 13  8659       WBA             West Bromwich Albion    210
# 14  8667       HUL             Hull City               210
# ...

# %% [markdown]
# ### Top 10 highest goal scoring teams in europe

# %%
gs <- select(teams, team_api_id, team_short_name, team_long_name, goals_scored)
top_n(arrange(gs, desc(goals_scored)),10)
# Out:
# Selecting by goals_scored
#    team_api_id team_short_name team_long_name    goals_scored
# 1   8634       BAR             FC Barcelona      849
# 2   8633       REA             Real Madrid CF    843
# 3   9925       CEL             Celtic            695
# 4   9823       BMU             FC Bayern Munich  653
# 5   8640       PSV             PSV               652
# 6   8593       AJA             Ajax              647
# 7   9931       BAS             FC Basel          619
# 8   8456       MCI             Manchester City   606
# 9   8455       CHE             Chelsea           583
# 10 10260       MUN             Manchester United 582
